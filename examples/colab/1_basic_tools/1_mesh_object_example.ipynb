# %% [markdown]
# <a href="https://colab.research.google.com/github/Josiah-Kunz/MGN-Public/blob/colab-examples/examples/colab/1_basic_tools/1_mesh_object_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dependencies

# %%
# %%capture

try:
    import google.colab  # noqa: F401
except ImportError:
    import ufl_legacy
    import fenics
else:
    try:
        import ufl_legacy
        import fenics
    except ImportError:
        # !wget "https://fem-on-colab.github.io/releases/fenics-install-release-real.sh" -O "/tmp/fenics-install.sh" && bash "/tmp/fenics-install.sh"
        import ufl_legacy
        import fenics

# !apt-get install -y libglu1-mesa -q
# !pip install gmsh meshio pint torch torch-geometric scikit-learn -q
# !pip install git+https://github.com/Josiah-Kunz/MGN-Public.git -q

import os
from main_package import MeshObject, Units

# !wget "https://raw.githubusercontent.com/Josiah-Kunz/MGN-Public/refs/heads/colab-examples/examples/local/cantilever/geometries/cantilever.stp" -O "cantilever.stp" -q

# %% [markdown]
# # Show Off Mesh

# %%
def main():
    mesh = MeshObject("cantilever.stp", 250, units=Units.SI_MM, force_2d=True)
    mesh.summary()
    mesh.visualize()
    mesh.analyze()

# %%
if __name__ == "__main__":
    main()
# Out:
# ...
# Mesh Summary: Cantilever
# ...
#
# Source:
#   File: cantilever.stp
#   Cache: .mesh_cache/cantilever_250_2d.xdmf
#   Mesh size parameter: 250 mm
#
# Mesh Statistics:
#   Dimension: 2D
#   Vertices: 624
#   Cells: 1038
#   Edges: 0
#
# Coordinate Ranges (mm):
#   X: [0.000, 25000.000] (extent: 25000.000)
#   Y: [-500.000, 500.000] (extent: 1000.000)
#
# Mesh Density:
#   Elements per unit length: ~0.04
# ...
# Deep Mesh Inspection: Cantilever
# ...
#
# Element Quality Metrics:
#   Aspect Ratio:
#     Mean: 1.193
#     Min: 1.000 (best = 1.0)
#     Max: 1.556
#     Std Dev: 0.156
#
#   Element Area mm^2:
#     Mean: 24084.778
#     Min: 15180.999
#     Max: 32604.287
#     Std Dev: 3661.483
#
# Quality Assessment:
#   Good (AR < 2.0): 1038 (100.0%)
#   Fair (2.0 ≤ AR < 5.0): 0 (0.0%)
#   Poor (AR ≥ 5.0): 0 (0.0%)
#   ✓ Mesh quality is acceptable
# ...
